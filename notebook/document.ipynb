# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a test document. I am using this document to test the functionality of the Document class in LangChain.",
    metadata={
        "source": "test_source"
        , "pages":1
        , "author": "test_author"
        , "date": "2024-06-10"}
)

doc
# Out:
# Document(metadata={'source': 'test_source', 'pages': 1, 'author': 'test_author', 'date': '2024-06-10'}, page_content='This is a test document. I am using this document to test the functionality of the Document class in LangChain.')

# %%
##create a  simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
##textloader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Diectory loader
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader(
    "../data/text_files"
    , glob="**/*.txt" ## pattern to match all files
    , loader_cls=TextLoader #loader class to use for loading the files
    , loader_kwargs={'encoding':'utf-8'}
    , show_progress=False
)

documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader
loader = DirectoryLoader(
    "../data/PDF"
    , glob="**/*.pdf" ## pattern to match all files
    , loader_cls=PyMuPDFLoader #loader class to use for loading the files
    , show_progress=False
)

documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'producer': 'Qt 5.15.13', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2026-07-20T12:27:10+00:00', 'source': '..\\data\\PDF\\Epicor_Complete_Revision_Guide.pdf', 'file_path': '..\\data\\PDF\\Epicor_Complete_Revision_Guide.pdf', 'total_pages': 23, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20260720122710Z', 'page': 0}, page_content='Epicor Interview — Complete Revision Guide\nProduct Developer (.NET, Angular, SQL) — Round 1, 21 July 2026\nEpicor — Product Developer (.NET, Angular, SQL) — Deep\nPrep Guide\nRound 1 (Teams) — 21 July 2026, 12 PM\nThis guide is built directly against the JD you shared: C#, .NET 8+, ASP.NET Core, Angular 15+, EF Core, SQL Server,\narchitecture patterns, testing (xUnit/Moq), Azure, Docker/K8s basics, auth (OAuth2/JWT/OIDC), and Agile. Given you’re 3 years\nin against a 3–5 year band, the interviewer will likely probe depth over breadth — expect “why,” not just “what.” Answer with a\nreason + a tiny example every time.'), Document(metadata={'producer': 'Qt 5.15.13', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2026-07-20T12:27:10+00:00', 'source': '..\\data\\PDF\\Epicor_Complete_Revision_Guide.pdf', 'file_path': '..\\data\\PDF\\Epicor_Complete_Revision_Guide.pdf', 'total_pages': 23, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20260720122710Z', 'page': 1}, page_content="1. C# / .NET Core Fundamentals\nQ1. What’s the difference between .NET Framework , .NET Core , and .NET 8 ? .NET Framework is Windows-only, legacy, no\nlonger under active feature development. .NET Core (now unified as just “.NET” from .NET 5 onward) is cross-platform, open\nsource, faster, modular via NuGet. .NET 8 is an LTS (Long Term Support) release — 3 years of support — vs. non-LTS releases\n(like .NET 7) that get 18 months. Say: “We run production on .NET 8 for the LTS guarantee.”\nQ2. Value types vs reference types? Value types ( struct , int , bool , enum ) live on the stack (or inline in containing\nobjects) and are copied on assignment. Reference types ( class , string , arrays) live on the heap; variables hold a\npointer/reference. string is a reference type but behaves immutably — every “modification” creates a new string object.\nBug-spotting example:\nFix: pass ref Point p if mutation is intended, or better, avoid mutable structs entirely.\nQ3. readonly vs const ? const is a compile-time constant, must be assigned at declaration, implicitly static. readonly is\nassigned at declaration or in the constructor, evaluated at runtime, can differ per instance.\nQ4. Boxing and unboxing — why does it matter for performance? Boxing wraps a value type in an object on the heap\n(implicit); unboxing extracts it back (explicit cast). Costs an allocation + GC pressure. Common silent-boxing trap:\nModern fix: use generic collections ( List<int> ) which avoid boxing entirely.\nQ5. IEnumerable vs IQueryable — this comes up constantly with EF Core. IEnumerable<T> executes in-memory (LINQ to\nObjects) — the whole sequence is already loaded, filtering happens client-side. IQueryable<T> builds an expression tree that’s\ntranslated into SQL and executed at the database, only when enumerated (deferred execution). Mixing them wrong is a classic\nperformance bug:\nQ6. Explain deferred execution and give a bug caused by it. LINQ queries (IQueryable/IEnumerable, not already\nmaterialized with .ToList() / .ToArray() / .Count() / .First() ) don’t run until enumerated. Classic bug — closure captures a\nvariable by reference, not value:\nAlso the “modified collection” bug — iterating and mutating the same List<T> throws InvalidOperationException because\ndeferred LINQ re-reads the source at enumeration time.\nQ7. async/await — what problem does it solve, and what’s a common deadlock bug? It frees the thread during I/O-\nbound wa ...

# %%
type(documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
from pathlib import Path
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders.excel import UnstructuredExcelLoader

excel_dir = Path("../data/EXCEL")

loader = DirectoryLoader(
    str(excel_dir),
    glob="**/*.xlsx",
    loader_cls=UnstructuredExcelLoader,
    show_progress=False,
)

documents = loader.load()
print(f"Loaded {len(documents)} documents")

if documents:
    print(documents[0].metadata)
else:
    print(f"No Excel files found in {excel_dir.resolve()}")
# Out:
# Loaded 3 documents
# {'source': '..\\data\\EXCEL\\AD2026-shares-2026-05-06-141341.xlsx'}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\rupam.pal\OneDrive - Euromonitor International\Personal Projects\RAG-Fundamentals\.venv\Scripts\python.exe: No module named pip
